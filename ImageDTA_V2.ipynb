# %%
# ==== 0. (already done) clone the repo ====
# !git clone https://github.com/neuhanli/ImageDTA.git
# Out:
# Cloning into 'ImageDTA'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 98 (delta 1), reused 0 (delta 0), pack-reused 93 (from 1)
# Receiving objects: 100% (98/98), 11.06 MiB | 24.00 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# 1. move into the repo
# %cd /content/ImageDTA

# 2. install the missing dependencies
# !pip install -q pandas numpy scipy networkx pillow tqdm
# Out:
# /content/ImageDTA

# %%
# 3. create the CSV files (this only has to be done once)
# !python create_csv.py      # outputs the four *_train/_test.csv files
# Out:
# convert data from DeepDTA for  kiba
#
# dataset: kiba
# train_fold: 98545
# test_fold: 19709
# convert data from DeepDTA for  davis
#
# dataset: davis
# train_fold: 25046
# test_fold: 5010

# %%
# 4a. train on the DAVIS dataset with GPU 0
# !python training.py 0 0    # 0=davis, 0=cuda:0

# 4b. (optional) train on the KIBA dataset with GPU 0
# !python training.py 1 0
# Out:
# Streaming output truncated to the last 5000 lines.
# process data 568/5010
# process data 569/5010
# process data 570/5010
# process data 571/5010
# process data 572/5010
# process data 573/5010
# process data 574/5010
# process data 575/5010
# process data 576/5010
# process data 577/5010
# process data 578/5010
# process data 579/5010
# process data 580/5010
# process data 581/5010
# process data 582/5010
# process data 583/5010
# process data 584/5010
# process data 585/5010
# process data 586/5010
# process data 587/5010
# process data 588/5010
# process data 589/5010
# process data 590/5010
# process data 591/5010
# process data 592/5010
# process data 593/5010
# process data 594/5010
# process data 595/5010
# process data 596/5010
# process data 597/5010
# process data 598/5010
# process data 599/5010
# process data 600/5010
# process data 601/5010
# process data 602/5010
# process data 603/5010
# process data 604/5010
# process data 605/5010
# process data 606/5010
# ...
